# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 from mappo import Mappo
#       2
# ----> 3 policy = Mappo()
#       4 policy.train()
#
# TypeError: Mappo.__init__() missing 1 required positional argument: 'env'
